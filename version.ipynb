# %%
! python --version
# Out:
# Python 3.12.7

# %%
! pip --version
# Out:
# pip 25.3 from c:\Users\subha\Desktop\Alfido-Tech-internship\.venv\Lib\site-packages\pip (python 3.12)

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.4'

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.10.7'

# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
import sklearn as sl

# %%
sl.__version__
# Out:
# '1.7.2'
